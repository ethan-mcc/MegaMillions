# %%
import sqlite3
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd
# pip install "gluonts[torch]"

# Connect to the SQLite database for training data
train_conn = sqlite3.connect('MegaMillions_Train.db')

# Query data from the database for training
query_train = "SELECT * FROM Interval_Data"
df_train = pd.read_sql_query(query_train, train_conn)
df_train

# Connect to the SQLite database for test data
test_conn = sqlite3.connect('MegaMillions_Test.db')

# Query data from the database for test
query_test = "SELECT * FROM Interval_Data"
df_test = pd.read_sql_query(query_test, test_conn)
df_test
# Out:
#       Draw Date Winning Numbers  Mega Ball  Multiplier
# 0    10/19/2018  15 23 53 65 70          7           2
# 1    10/19/2018  15 23 53 65 70          7           2
# 2    10/19/2018  15 23 53 65 70          7           2
# 3    10/19/2021  03 12 13 19 52          1           3
# 4    10/19/2021  03 12 13 19 52          1           3
# ..          ...             ...        ...         ...
# 628  12/31/2019  30 44 49 53 56         11           3
# 629  12/31/2019  30 44 49 53 56         11           3
# 630  12/31/2021  02 05 30 46 61          8           3
# 631  12/31/2021  02 05 30 46 61          8           3
# 632  12/31/2021  02 05 30 46 61          8           3
#
# [633 rows x 4 columns]

# %%
from gluonts.dataset.common import ListDataset
from gluonts.torch.model.deepar import DeepAREstimator
from gluonts.evaluation import make_evaluation_predictions, Evaluator
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# pip install "gluonts[torch]"

# Convert 'Draw Date' to datetime
df_train['Draw Date'] = pd.to_datetime(df_train['Draw Date'])

# Prepare DataFrame for predicting Winning Numbers
winning_numbers = df_train['Winning Numbers'].str.split(' ', expand=True)
winning_numbers.columns = [f'Ball_{i+1}' for i in winning_numbers.columns]
df_train = pd.concat([df_train, winning_numbers], axis=1)

# Prepare data for predicting Winning Numbers and Mega Ball
winning_numbers_df = df_train[['Draw Date'] + [f'Ball_{i+1}' for i in range(5)] + ['Mega Ball']].copy()
winning_numbers_df.columns = ['ds'] + [f'y_{i+1}' for i in range(5)] + ['y_mega_ball']  # Rename columns

# Min-Max scaling for the numerical columns
scaler = MinMaxScaler()
numerical_columns = [f'y_{i+1}' for i in range(5)] + ['y_mega_ball']
winning_numbers_df[numerical_columns] = scaler.fit_transform(winning_numbers_df[numerical_columns])

# Create a ListDataset for multiple values prediction using the scaled data
data = [
    {
        "start": winning_numbers_df.iloc[i]['ds'],
        "target": winning_numbers_df.iloc[i][numerical_columns].values,
        "feat_dynamic_real": [[None] * 6]  
    }
    for i in range(len(winning_numbers_df))
]

# Frequency of data 
freq = "D"

# Create ListDataset
train_ds = ListDataset(data, freq=freq)

# Define DeepAR estimator for predicting 5 white balls and 1 Mega Ball
estimator = DeepAREstimator(prediction_length=6, freq=freq, context_length=30, num_layers=3)

# Train the model
predictor = estimator.train(training_data=train_ds)

# Make predictions for Winning Numbers and Mega Ball
forecast_it, ts_it = make_evaluation_predictions(dataset=train_ds, predictor=predictor, num_samples=10)

forecasts = list(forecast_it)
tss = list(ts_it)

# Calculate metrics
evaluator = Evaluator()
agg_metrics, item_metrics = evaluator(tss, forecasts, num_series=len(train_ds))

mae_white_balls = agg_metrics["MASE"]
mse_white_balls = agg_metrics["MSE"]
rmse_white_balls = agg_metrics["RMSE"]

print(f"MAE for White Balls and Mega Ball: {mae_white_balls}")
print(f"MSE for White Balls and Mega Ball: {mse_white_balls}")
print(f"RMSE for White Balls and Mega Ball: {rmse_white_balls}")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\lightning\pytorch\trainer\configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name  | Type        | Params | In sizes                                                        | Out sizes
# ----------------------------------------------------------------------------------------------------------------------
# 0 | model | DeepARModel | 39.0 K | [[1, 1], [1, 1], [1, 1122, 4], [1, 1122], [1, 1122], [1, 6, 4]] | [1, 100, 6]
# ----------------------------------------------------------------------------------------------------------------------
# 39.0 K    Trainable params
# 0         Non-trainable params
# 39.0 K    Total params
# 0.156     Total estimated model params size (MB)
# Training: |                                                                                                   …
# Epoch 0, global step 50: 'train_loss' reached 8.16653 (best 8.16653), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 6.81346 (best 6.81346), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 6.63779 (best 6.63779), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 6.57629 (best 6.57629), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 6.49156 (best 6.49156), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 6.45377 (best 6.45377), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 6.41615 (best 6.41615), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 6.36384 (best 6.36384), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 6.35785 (best 6.35785), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 6.31043 (best 6.31043), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 6.27313 (best 6.27313), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached 6.27229 (best 6.27229), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 6.24056 (best 6.24056), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached 6.21257 (best 6.21257), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' reached 6.19220 (best 6.19220), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' reached 6.17703 (best 6.17703), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' reached 6.16860 (best 6.16860), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached 6.13303 (best 6.13303), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' was not in top 1
# Epoch 20, global step 1050: 'train_loss' reached 6.11684 (best 6.11684), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=20-step=1050.ckpt' as top 1
# Epoch 21, global step 1100: 'train_loss' reached 6.09288 (best 6.09288), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=21-step=1100.ckpt' as top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' reached 6.07438 (best 6.07438), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=23-step=1200.ckpt' as top 1
# Epoch 24, global step 1250: 'train_loss' was not in top 1
# Epoch 25, global step 1300: 'train_loss' reached 6.07047 (best 6.07047), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=25-step=1300.ckpt' as top 1
# Epoch 26, global step 1350: 'train_loss' reached 6.05278 (best 6.05278), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=26-step=1350.ckpt' as top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' reached 6.03100 (best 6.03100), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' reached 6.01559 (best 6.01559), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' reached 6.00699 (best 6.00699), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=31-step=1600.ckpt' as top 1
# Epoch 32, global step 1650: 'train_loss' reached 5.98409 (best 5.98409), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=32-step=1650.ckpt' as top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' reached 5.98017 (best 5.98017), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=34-step=1750.ckpt' as top 1
# Epoch 35, global step 1800: 'train_loss' reached 5.97422 (best 5.97422), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' reached 5.95171 (best 5.95171), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=37-step=1900.ckpt' as top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' reached 5.94001 (best 5.94001), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' reached 5.93131 (best 5.93131), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=40-step=2050.ckpt' as top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' reached 5.92552 (best 5.92552), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=42-step=2150.ckpt' as top 1
# Epoch 43, global step 2200: 'train_loss' reached 5.90482 (best 5.90482), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=43-step=2200.ckpt' as top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' reached 5.90317 (best 5.90317), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=45-step=2300.ckpt' as top 1
# Epoch 46, global step 2350: 'train_loss' reached 5.89747 (best 5.89747), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' reached 5.87545 (best 5.87545), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=48-step=2450.ckpt' as top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# Epoch 50, global step 2550: 'train_loss' reached 5.87244 (best 5.87244), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=50-step=2550.ckpt' as top 1
# Epoch 51, global step 2600: 'train_loss' reached 5.85796 (best 5.85796), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=51-step=2600.ckpt' as top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' reached 5.85050 (best 5.85050), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=53-step=2700.ckpt' as top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' reached 5.83217 (best 5.83217), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=56-step=2850.ckpt' as top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' reached 5.82765 (best 5.82765), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=58-step=2950.ckpt' as top 1
# Epoch 59, global step 3000: 'train_loss' reached 5.81125 (best 5.81125), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=59-step=3000.ckpt' as top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' reached 5.81047 (best 5.81047), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=61-step=3100.ckpt' as top 1
# Epoch 62, global step 3150: 'train_loss' reached 5.79713 (best 5.79713), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=62-step=3150.ckpt' as top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' was not in top 1
# Epoch 65, global step 3300: 'train_loss' reached 5.79491 (best 5.79491), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=65-step=3300.ckpt' as top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' reached 5.77082 (best 5.77082), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=67-step=3400.ckpt' as top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' reached 5.77000 (best 5.77000), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=69-step=3500.ckpt' as top 1
# Epoch 70, global step 3550: 'train_loss' reached 5.75444 (best 5.75444), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=70-step=3550.ckpt' as top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' reached 5.74893 (best 5.74893), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=72-step=3650.ckpt' as top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' was not in top 1
# Epoch 75, global step 3800: 'train_loss' reached 5.74418 (best 5.74418), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=75-step=3800.ckpt' as top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' reached 5.73244 (best 5.73244), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=77-step=3900.ckpt' as top 1
# Epoch 78, global step 3950: 'train_loss' reached 5.72200 (best 5.72200), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=78-step=3950.ckpt' as top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' reached 5.72198 (best 5.72198), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=80-step=4050.ckpt' as top 1
# Epoch 81, global step 4100: 'train_loss' reached 5.70336 (best 5.70336), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=81-step=4100.ckpt' as top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' reached 5.70285 (best 5.70285), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=84-step=4250.ckpt' as top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' reached 5.68864 (best 5.68864), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=86-step=4350.ckpt' as top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' reached 5.68389 (best 5.68389), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=88-step=4450.ckpt' as top 1
# Epoch 89, global step 4500: 'train_loss' reached 5.67741 (best 5.67741), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=89-step=4500.ckpt' as top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' reached 5.67700 (best 5.67700), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=91-step=4600.ckpt' as top 1
# Epoch 92, global step 4650: 'train_loss' reached 5.65938 (best 5.65938), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=92-step=4650.ckpt' as top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' reached 5.65867 (best 5.65867), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=95-step=4800.ckpt' as top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' reached 5.64160 (best 5.64160), saving model to 'C:\\Users\\Ethan\\PycharmProjects\\MegaMillionsProject\\lightning_logs\\version_18\\checkpoints\\epoch=97-step=4900.ckpt' as top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Running evaluation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2529/2529 [00:13<00:00, 182.19it/s]
# MAE for White Balls and Mega Ball: nan
# MSE for White Balls and Mega Ball: 0.2998087632916529
# RMSE for White Balls and Mega Ball: 0.5475479552437876
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)

# %%
# Convert 'Draw Date' to datetime
df_test['Draw Date'] = pd.to_datetime(df_test['Draw Date'])

# Split the 'Winning Numbers' into separate columns for white balls
winning_numbers_test = df_test['Winning Numbers'].str.split(' ', expand=True)
winning_numbers_test.columns = [f'Ball_{i+1}' for i in winning_numbers_test.columns]
df_test = pd.concat([df_test, winning_numbers_test], axis=1)

# Convert 'Ball' columns to integers
ball_columns_test = [f'Ball_{i+1}' for i in range(5)]  # Assuming 5 white balls
for col in ball_columns_test:
    df_test[col] = pd.to_numeric(df_test[col])

# Prepare data for predicting Winning Numbers and Mega Ball on test data
test_data = df_test[['Draw Date'] + ball_columns_test + ['Mega Ball']].copy()
test_data.columns = ['ds'] + [f'y_{i+1}' for i in range(5)] + ['y_mega_ball']  # Rename columns

# Create a ListDataset for the test data including white balls and Mega Ball
test_data_list = [
    {
        "start": test_data.iloc[i]['ds'],
        "target": test_data.iloc[i][[f'y_{i+1}' for i in range(5)] + ['y_mega_ball']].values,
        "feat_dynamic_real": [[None] * 6]  # 2D array of Nones for features (if any)
    }
    for i in range(len(test_data))
]

# Frequency of data (assuming daily frequency)
freq = "D"

# Create ListDataset for the test data
test_ds = ListDataset(test_data_list, freq=freq)

# Use the trained predictor to make predictions on the test data
forecast_it_test, ts_it_test = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100  # Number of sample paths to draw while making predictions
)

forecasts_test = list(forecast_it_test)
tss_test = list(ts_it_test)
# Calculate metrics or perform any analysis needed for evaluation
evaluator = Evaluator()
agg_metrics_test, item_metrics_test = evaluator(iter(tss_test), iter(forecasts_test), num_series=len(test_ds))

# Retrieve metrics for white balls and Mega Ball from the test data evaluation
mae_white_balls_test = agg_metrics_test["MASE"]
mse_white_balls_test = agg_metrics_test["MSE"]
rmse_white_balls_test = agg_metrics_test["RMSE"]

print(f"MAE for White Balls on test data: {mae_white_balls_test}")
print(f"MSE for White Balls on test data: {mse_white_balls_test}")
print(f"RMSE for White Balls on test data: {rmse_white_balls_test}")
# Out:
# Running evaluation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 633/633 [00:03<00:00, 169.75it/s]
# MAE for White Balls on test data: nan
# MSE for White Balls on test data: 1354.691943127962
# RMSE for White Balls on test data: 36.806140019403855
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# C:\Users\Ethan\PycharmProjects\pythonProject6\venv\lib\site-packages\pandas\core\dtypes\astype.py:134: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)

# %%
def predict_mega_ball(model, date):
    # Prepare data for prediction based on the provided date
    prediction_data = pd.DataFrame({'ds': [date], 'y': [0]})  # Replace 0 with a default value for prediction

    # Convert 'ds' column to datetime
    prediction_data['ds'] = pd.to_datetime(prediction_data['ds'])

    # Create a ListDataset for prediction
    prediction_ds = ListDataset(
        [
            {
                "start": prediction_data["ds"].values[0],  # Assuming a single time series
                "target": prediction_data["y"].values,
                "feat_dynamic_real": [[None]]  # 2D array of a single None
            }
        ],
        freq="D"
    )

    # Make prediction using the provided model
    forecast_it_pred = model.predict(prediction_ds)

    # Extract the predicted value for the Mega Ball
    forecast = next(forecast_it_pred)
    predicted_mega_ball = forecast.mean[0]

    return predicted_mega_ball



predicted_number = predict_mega_ball(predictor, '2023-12-31')  
print(f"Predicted Mega Ball number for 2023-12-31: {predicted_number}")
# Out:
# Predicted Mega Ball number for 2023-12-31: -2.437233970198349e-09

# %%
# Frequency of data 
freq = "D"

# Create a ListDataset for the input date prediction
def predict_numbers(input_date):
    prediction_data = [
        {
            "start": input_date,
            "target": [None, None, None, None, None, None],  # Placeholder for predictions
            "feat_dynamic_real": [[None] * 6]  
        }
    ]

    predict_ds = ListDataset(prediction_data, freq=freq)

    # Make predictions for the input date
    forecast_it, ts_it = make_evaluation_predictions(dataset=predict_ds, predictor=predictor, num_samples=10)

    forecasts = list(forecast_it)
    tss = list(ts_it)

    # Return the predicted values for white balls and Mega Ball
    return forecasts[0].samples.mean(axis=0)[:5], forecasts[0].samples.mean(axis=0)[-1]

input_date = pd.to_datetime('2023-12-1')
white_balls_pred, mega_ball_pred = predict_numbers(input_date)

# Assuming white_balls_pred and mega_ball_pred are the predicted values
combined_predictions = np.concatenate((white_balls_pred, np.array([mega_ball_pred])))

# Reshape the combined predictions array to fit the scaler
combined_predictions = combined_predictions.reshape(1, -1)


# Fit the scaler on the combined predictions
scaler.fit(combined_predictions)

# Scale the combined predictions
scaled_combined_predictions = combined_scaler.transform(combined_predictions)

# Now, you have the combined and scaled predictions
print(f"Scaled Combined Predictions: {scaled_combined_predictions}")
# Out:
# Scaled Combined Predictions: [[ 1.7714401e-09  6.7203447e-09 -5.6036285e-08 -1.9172457e-08
#    1.2283897e-08 -2.0033717e-08]]
